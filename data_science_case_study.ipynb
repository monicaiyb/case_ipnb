# %% [markdown]
# # Data Science Case Study
# In this case, you are tasked to find insights about the dataset provided.

# %%
# Import any libraries you may need to get any insights.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The table below describes each of the columns in the dataset:

# %% [markdown]
# | Column | Definition |
# | --- | --- |
# | Gender | Gender of the research subject |
# | Age | Age of the research subject|
# | Height | Height of the research subject|
# | Weight | Weight of the research subject |
# | family_history_with_overweight | family history of obesity |
# | FAVC | Do you eat high calorific food frequently? |
# | FCVC | Do you usually eat vegetables in your meals? |
# | NCP | How many meals do you have daily? |
# | CAEC | Do you eat any food between meals? |
# | SMOKE | Does the research subject smoke |
# | CH2O | How much water do you drink daily |
# | SCC | Do you monitor the calories you eat daily |
# | FAF | How often do you exercise? |
# | TUE | how much time do you use technological devices such as cell phone? |
# | CALC | How often do you drink alcohol |
# | MTRANS | Which transportation mode do you use most frequently? |
# | Weight_classification | The weight classification given the features. |

# %%
df = pd.read_csv('weight_class_data.csv')

# %% [markdown]
# ### Perform and in depth exploratory data analysis to understand the variables in the dataset and their relationship.

# %%
# Run your EDA here.
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS Weight_classification
# 0             no  Public_Transportation         Normal_Weight
# 1      Sometimes  Public_Transportation         Normal_Weight
# 2     Frequently  Public_Transportation         Normal_Weight
# 3     Frequently                Walking    Overweight_Level_I
# 4      Sometimes  Public_Transportation   Overweight_Level_II
# ...          ...                    ...                   ...
# 2106   Sometimes  Public_Transportation      Obesity_Type_III
# 2107   Sometimes  Public_Transportation      Obesity_Type_III
# 2108   Sometimes  Public_Transportation      Obesity_Type_III
# 2109   Sometimes  Public_Transportation      Obesity_Type_III
# 2110   Sometimes  Public_Transportation      Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
#To check first what the data set looks like for only the first 10 columns
df.head(8)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 5  3.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 6  3.0  Sometimes    no   2.0   no  1.0  0.0   Sometimes
# 7  3.0  Sometimes    no   2.0   no  3.0  0.0   Sometimes
#
#                   MTRANS Weight_classification
# 0  Public_Transportation         Normal_Weight
# 1  Public_Transportation         Normal_Weight
# 2  Public_Transportation         Normal_Weight
# 3                Walking    Overweight_Level_I
# 4  Public_Transportation   Overweight_Level_II
# 5             Automobile         Normal_Weight
# 6              Motorbike         Normal_Weight
# 7  Public_Transportation         Normal_Weight

# %%
df.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# Weight_classification              object
# dtype: object

# %%
# To check summary of entries in the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  Weight_classification           2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
# Check the last fields in the dataset
df.tail()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O SCC       FAF       TUE  \
# 2106  yes   3.0  3.0  Sometimes    no  1.728139  no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130  no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193  no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339  no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513  no  1.026452  0.714137
#
#            CALC                 MTRANS Weight_classification
# 2106  Sometimes  Public_Transportation      Obesity_Type_III
# 2107  Sometimes  Public_Transportation      Obesity_Type_III
# 2108  Sometimes  Public_Transportation      Obesity_Type_III
# 2109  Sometimes  Public_Transportation      Obesity_Type_III
# 2110  Sometimes  Public_Transportation      Obesity_Type_III

# %%
# 
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %%
# Aggregating specific columns instead of using predefined statistics
df.agg(
    {
        "Age": ["min", "max", "median", "skew"],
        "Height": ["min", "max", "median", "mean"],
    }
)
# Out:
#              Age    Height
# min     14.00000  1.450000
# max     61.00000  1.980000
# median  22.77789  1.700499
# skew     1.52910       NaN
# mean         NaN  1.701677

# %%
# Sorting through data to look for any outliers
df.sort_values(by="Age").head(20)
# Out:
#       Gender        Age    Height     Weight family_history_with_overweight  \
# 415     Male  14.000000  1.710000  72.000000                            yes
# 116   Female  15.000000  1.650000  86.000000                            yes
# 309   Female  16.000000  1.660000  58.000000                             no
# 295   Female  16.000000  1.660000  58.000000                             no
# 302     Male  16.000000  1.840000  45.000000                            yes
# 312   Female  16.000000  1.600000  57.000000                             no
# 389   Female  16.000000  1.610000  65.000000                            yes
# 385   Female  16.000000  1.550000  45.000000                             no
# 276     Male  16.000000  1.670000  50.000000                            yes
# 290     Male  16.000000  1.820000  71.000000                            yes
# 303   Female  16.000000  1.570000  49.000000                             no
# 876   Female  16.093234  1.608914  65.000000                            yes
# 1301  Female  16.129279  1.650000  85.583485                            yes
# 785   Female  16.172992  1.603842  65.000000                            yes
# 554     Male  16.198153  1.691007  52.629374                             no
# 953   Female  16.240576  1.616533  65.062945                            yes
# 563   Female  16.270434  1.818268  47.124717                             no
# 553     Male  16.306870  1.752755  50.000000                             no
# 791   Female  16.306870  1.616366  67.183128                            yes
# 959   Female  16.370009  1.613921  66.738769                            yes
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF  \
# 415   yes  3.000000  3.000000   Sometimes    no  3.000000   no  2.000000
# 116   yes  3.000000  3.000000   Sometimes    no  1.000000   no  3.000000
# 309    no  2.000000  1.000000   Sometimes    no  1.000000   no  0.000000
# 295    no  2.000000  1.000000   Sometimes    no  1.000000   no  0.000000
# 302   yes  3.000000  3.000000      Always    no  3.000000   no  3.000000
# 312   yes  3.000000  3.000000   Sometimes    no  1.000000   no  3.000000
# 389   yes  1.000000  1.000000   Sometimes    no  2.000000   no  0.000000
# 385   yes  2.000000  3.000000  Frequently    no  2.000000   no  1.000000
# 276   yes  2.000000  1.000000  Frequently    no  3.000000   no  1.000000
# 290   yes  2.000000  3.000000  Frequently    no  2.000000   no  2.000000
# 303   yes  2.000000  4.000000      Always    no  2.000000   no  0.000000
# 876   yes  1.321028  1.000000   Sometimes    no  2.000000  yes  0.371452
# 1301  yes  2.954996  3.000000   Sometimes    no  1.000000   no  2.091862
# 785   yes  2.543563  1.000000   Sometimes    no  2.000000  yes  0.694281
# 554   yes  2.000000  2.000986   Sometimes    no  2.673835   no  0.992950
# 953   yes  2.388168  1.000000   Sometimes    no  1.438018  yes  0.110887
# 563   yes  3.000000  3.286431   Sometimes    no  2.148146   no  2.458237
# 553   yes  2.310423  3.558637   Sometimes    no  1.787843   no  1.926592
# 791   yes  1.620845  1.000000   Sometimes    no  2.000000  yes  0.926592
# 959   yes  2.206399  1.000000   Sometimes    no  2.000000  yes  0.948930
#
#            TUE       CALC                 MTRANS Weight_classification
# 415   1.000000         no                Walking         Normal_Weight
# 116   2.000000         no                Walking        Obesity_Type_I
# 309   1.000000         no                Walking         Normal_Weight
# 295   1.000000         no                Walking         Normal_Weight
# 302   2.000000  Sometimes                Walking   Insufficient_Weight
# 312   0.000000         no  Public_Transportation         Normal_Weight
# 389   0.000000         no  Public_Transportation    Overweight_Level_I
# 385   1.000000         no  Public_Transportation         Normal_Weight
# 276   0.000000         no  Public_Transportation   Insufficient_Weight
# 290   1.000000  Sometimes  Public_Transportation         Normal_Weight
# 303   1.000000  Sometimes  Public_Transportation         Normal_Weight
# 876   0.965604         no  Public_Transportation    Overweight_Level_I
# 1301  1.060530         no  Public_Transportation        Obesity_Type_I
# 785   1.056911  Sometimes  Public_Transportation    Overweight_Level_I
# 554   0.474836  Sometimes  Public_Transportation   Insufficient_Weight
# 953   1.165817         no  Public_Transportation    Overweight_Level_I
# 563   1.273333  Sometimes  Public_Transportation   Insufficient_Weight
# 553   0.828549  Sometimes  Public_Transportation   Insufficient_Weight
# 791   1.657098         no  Public_Transportation    Overweight_Level_I
# 959   1.772463         no  Public_Transportation    Overweight_Level_I

# %%
# Sorting through data to look for any outliers
df.sort_values(by="Age").tail(20)
# Out:
#       Gender        Age    Height     Weight family_history_with_overweight  \
# 1386  Female  43.719395  1.584322  80.986496                            yes
# 1490  Female  43.726081  1.592316  77.001030                            yes
# 137     Male  44.000000  1.600000  80.000000                            yes
# 1063  Female  45.000000  1.675953  79.668320                            yes
# 492     Male  45.000000  1.700000  86.000000                             no
# 169   Female  45.000000  1.630000  77.000000                            yes
# 1208  Female  45.821267  1.687326  80.413997                            yes
# 1101    Male  46.491859  1.718097  88.600878                            yes
# 1286  Female  47.283374  1.643786  81.978743                            yes
# 1179    Male  47.706100  1.743935  84.729197                            yes
# 1034    Male  50.832559  1.745528  82.130728                            yes
# 232   Female  51.000000  1.590000  50.000000                            yes
# 21    Female  52.000000  1.690000  87.000000                            yes
# 161     Male  55.000000  1.650000  80.000000                             no
# 92      Male  55.000000  1.780000  84.000000                            yes
# 1158    Male  55.022494  1.673394  80.400306                            yes
# 1088    Male  55.137881  1.657221  80.993213                            yes
# 1013    Male  55.246250  1.769269  80.491339                             no
# 252     Male  56.000000  1.790000  90.000000                            yes
# 133   Female  61.000000  1.650000  66.000000                             no
#
#      FAVC      FCVC       NCP        CAEC SMOKE      CH2O  SCC       FAF  TUE  \
# 1386  yes  2.186322  2.900915   Sometimes    no  2.471033   no  0.256113  0.0
# 1490  yes  2.000000  3.000000   Sometimes    no  2.806922   no  0.000000  0.0
# 137    no  2.000000  3.000000   Sometimes   yes  3.000000   no  0.000000  0.0
# 1063  yes  2.598051  3.000000   Sometimes    no  1.000000   no  0.000000  0.0
# 492   yes  3.000000  3.000000  Frequently    no  1.000000   no  0.000000  0.0
# 169   yes  2.000000  3.000000  Frequently    no  1.000000   no  0.000000  0.0
# 1208  yes  2.076689  3.000000   Sometimes    no  1.026729   no  0.647798  0.0
# 1101  yes  2.129969  3.000000   Sometimes    no  1.568035   no  0.870127  0.0
# 1286  yes  2.037585  1.418985   Sometimes    no  1.827351   no  0.000000  0.0
# 1179  yes  2.535315  3.000000   Sometimes    no  1.146595   no  0.313810  0.0
# 1034  yes  2.000000  3.000000   Sometimes    no  1.774778   no  0.943266  0.0
# 232    no  3.000000  3.000000   Sometimes   yes  3.000000  yes  2.000000  0.0
# 21    yes  3.000000  1.000000   Sometimes   yes  2.000000   no  0.000000  0.0
# 161   yes  2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  0.0
# 92     no  3.000000  4.000000  Frequently    no  3.000000  yes  3.000000  0.0
# 1158  yes  2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  0.0
# 1088  yes  2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  0.0
# 1013  yes  2.000000  3.000000   Sometimes    no  2.000000   no  1.000000  0.0
# 252    no  2.000000  3.000000   Sometimes   yes  2.000000   no  1.000000  0.0
# 133   yes  3.000000  3.000000      Always    no  2.000000   no  1.000000  1.0
#
#             CALC                 MTRANS Weight_classification
# 1386          no             Automobile        Obesity_Type_I
# 1490   Sometimes             Automobile        Obesity_Type_I
# 137           no              Motorbike        Obesity_Type_I
# 1063          no             Automobile   Overweight_Level_II
# 492           no             Automobile   Overweight_Level_II
# 169           no             Automobile   Overweight_Level_II
# 1208          no             Automobile   Overweight_Level_II
# 1101          no             Automobile   Overweight_Level_II
# 1286          no             Automobile        Obesity_Type_I
# 1179          no             Automobile   Overweight_Level_II
# 1034          no             Automobile   Overweight_Level_II
# 232           no  Public_Transportation         Normal_Weight
# 21            no             Automobile        Obesity_Type_I
# 161           no             Automobile   Overweight_Level_II
# 92    Frequently                Walking    Overweight_Level_I
# 1158          no             Automobile   Overweight_Level_II
# 1088          no             Automobile   Overweight_Level_II
# 1013          no             Automobile   Overweight_Level_II
# 252   Frequently             Automobile   Overweight_Level_II
# 133   Frequently  Public_Transportation         Normal_Weight

# %%
# Check for missing valus
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# Weight_classification             0
# dtype: int64

# %%
air_quality.plot.box()

# %%
# Visual check of the dataset
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Visual check of dataset based on a weight and age
df.plot.scatter(x="Weight",y="Age")
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Age'>

# %%
# Visual check of dataset based on weight  and CH20
df.plot.scatter(x="Height",y="Weight")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
# To checkout the correlation between different variables
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# To see the effect of height
sns.histplot(df.Height,bins=10)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
# To see the effect of height
sns.histplot(df.Weight,bins=10)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Count'>

# %% [markdown]
# ### Considering the `Weight_classification` feature as the target, is this a balanced dataset? What would be the top 5 predictive features to use for baseline modeling? What sort of feature engineering would you perform (no need to implement this)?

# %%
# Answer here.

# %% [markdown]
# ### Considering this particular dataset, and `Weight_classification` as the target, is it necessary to build a machine learning model?
